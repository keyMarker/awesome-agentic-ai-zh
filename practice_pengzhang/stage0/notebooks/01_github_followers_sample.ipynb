# %%
import requests

# %%
response = requests.get("https://api.github.com/users/keymarker")

# %%
type(response)
# Out:
# requests.models.Response

# %%
help(response.json)
# Out:
# Help on method json in module requests.models:
#
# json(**kwargs: 'Any') -> 'Any' method of requests.models.Response instance
#     Decodes the JSON response body (if any) as a Python object.
#
#     This may return a dictionary, list, etc. depending on what is in the response.
#
#     :param \*\*kwargs: Optional arguments that ``json.loads`` takes.
#     :raises requests.exceptions.JSONDecodeError: If the response body does not
#         contain valid json.

# %%
data = response.json()

# %%
data
# Out:
# {'login': 'keyMarker',
#  'id': 13046056,
#  'node_id': 'MDQ6VXNlcjEzMDQ2MDU2',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/13046056?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/keyMarker',
#  'html_url': 'https://github.com/keyMarker',
#  'followers_url': 'https://api.github.com/users/keyMarker/followers',
#  'following_url': 'https://api.github.com/users/keyMarker/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/keyMarker/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/keyMarker/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/keyMarker/subscriptions',
#  'organizations_url': 'https://api.github.com/users/keyMarker/orgs',
#  'repos_url': 'https://api.github.com/users/keyMarker/repos',
#  'events_url': 'https://api.github.com/users/keyMarker/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/keyMarker/received_events',
#  'type': 'User',
#  'user_view_type': 'public',
#  'site_admin': False,
#  'name': None,
#  'company': None,
#  'blog': '',
#  'location': None,
#  'email': None,
#  'hireable': None,
#  'bio': None,
#  'twitter_username': None,
#  'public_repos': 10,
#  'public_gists': 0,
#  'followers': 1,
#  'following': 2,
#  'created_at': '2015-06-25T08:04:10Z',
#  'updated_at': '2026-04-07T06:39:08Z'}

# %%
followers_count = data['followers']

# %%
print(f"User has {followers_count} followers on GitHub.")
# Out:
# User has 1 followers on GitHub.
